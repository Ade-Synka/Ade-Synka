# %%
import arxiv
import pandas as pd
from langdetect import detect
import datetime
import pdfreader
from io import BytesIO
from pdfreader import PDFDocument, SimplePDFViewer
import re
import json
from pdfminer.high_level import extract_text
from collections import defaultdict

# %%
paper = next(arxiv.Client().results(arxiv.Search(id_list=["1605.08386v1"])))
paper.download_pdf('.\paper_storage', filename='article_001_labeled(1).pdf')
# Out:
# '.\\paper_storage\\article_001_labeled(1).pdf'

# %%
SUMMARY = paper.summary
TITLE = paper.title
LANGUAGE = detect(SUMMARY)
PUBLISHED_DATE = paper.published.strftime("%Y-%m-%d %H:%M:%S %Z")
AUTHORS = [author.name for author in paper.authors]

# %%
file_name = r'paper_storage\article_001_labeled(1).pdf'

with open(file_name, "rb") as f:
    stream = BytesIO(f.read())
doc2 = PDFDocument(stream)

# %%
import re
import json
from pdfminer.high_level import extract_text

SECTION_TITLES = [
    "Abstract", "Introduction", "Related Work", "Background",
    "Method", "Approach", "Experiments", "Results",
    "Conclusion", "Discussion"
]

def extract_pdf_text(stream):
    return extract_text(stream)

def build_section_regex(titles):
    pattern = '|'.join([fr'\b{re.escape(title)}\b' for title in titles])
    return re.compile(fr'(?P<header>{pattern})', re.IGNORECASE)

def split_sections(text, section_regex):
    sections = []
    matches = list(section_regex.finditer(text))
    
    for i, match in enumerate(matches):
        title = match.group('header').strip().title()
        start = match.start()
        end = matches[i + 1].start() if i + 1 < len(matches) else len(text)
        content = text[start:end].strip()
        sections.append({
            "name": title,
            "text": content
        })
    return sections

def build_ldjson_from_pdf(stream, title, published_date, language, summary, authors):
    """
    Build ld+json structured metadata from a PDF stream and metadata.
    """
    raw_text = extract_pdf_text(stream)
    section_regex = build_section_regex(SECTION_TITLES)
    sections = split_sections(raw_text, section_regex)

    # Prefer the passed summary but fall back to Abstract section if summary is empty
    abstract = summary.strip() if summary else ""
    if not abstract:
        for section in sections:
            if section["name"].lower() == "abstract":
                abstract = section["text"]
                sections.remove(section)
                break

    ld_json = {
        "name": title,
        "datePublished": published_date,
        "inLanguage": language,
        "author": [{"@type": "Person", "name": name} for name in authors],
        "abstract": abstract,
        "articleBody": sections
    }

    return json.dumps(ld_json, indent=2)

with open(r"paper_storage\article_001_labeled(1).pdf", "rb") as f:
    result_json = build_ldjson_from_pdf(f, TITLE, PUBLISHED_DATE, LANGUAGE, SUMMARY, AUTHORS)
    print(result_json)
# Out:
# {
#   "name": "Heat-bath random walks with Markov bases",
#   "datePublished": "2016-05-26 17:59:46 UTC",
#   "inLanguage": "en",
#   "author": [
#     {
#       "@type": "Person",
#       "name": "Caprice Stanley"
#     },
#     {
#       "@type": "Person",
#       "name": "Tobias Windisch"
#     }
#   ],
#   "abstract": "Graphs on lattice points are studied whose edges come from a finite set of\nallowed moves of arbitrary length. We show that the diameter of these graphs on\nfibers of a fixed integer matrix can be bounded from above by a constant. We\nthen study the mixing behaviour of heat-bath random walks on these graphs. We\nalso state explicit conditions on the set of moves so that the heat-bath random\nwalk, a generalization of the Glauber dynamics, is an expander in fixed\ndimension.",
#   "articleBody": [
#     {
#       "name": "Abstract",
#       "text": "Abstract. Graphs on lattice points are studied whose edges come from a \ufb01nite set of\nallowed moves of arbitrary length. We show that the diameter of these graphs on \ufb01bers of a\n\ufb01xed integer matrix can be bounded from above by a constant. We then study the mixing\nbehaviour of heat-bath random walks on these graphs. We also state explicit conditions\non the set of moves so that the heat-bath random walk, a generalization of the Glauber\ndynamics, is an expander in \ufb01xed dimension.\n\n]\n\nO\nC\n.\nh\nt\na\nm\n\n[\n\n1\nv\n6\n8\n3\n8\n0\n.\n5\n0\n6\n1\n:\nv\ni\nX\nr\na\n\nContents"
#     },
#     {
#       "name": "Introduction",
#       "text": "Introduction\n\n1.\n2. Graphs and statistics\n3. Bounds on the diameter\n4. Heat-bath random walks\n5. Augmenting Markov bases\nReferences\n\n1."
#     },
#     {
#       "name": "Introduction",
#       "text": "Introduction\n\n1\n3\n4\n8\n14\n19\n\nF \u2282\n\nM \u2282\n\nA \ufb01ber graph is a graph on the \ufb01nitely many lattice points\n\nZd of a polytope where\ntwo lattice points are connected by an edge if their di\ufb00erence lies in a \ufb01nite set of allowed\nZd. The implicit structure of these graphs makes them a useful tool to explore\nmoves\nthe set of lattice points randomly: At the current lattice point u\n\u2208 F\n\u2208 \u00b1M\nand stays at u otherwise.\nis sampled and the random walk moves along m if u + m\nThe corresponding Markov chain is irreducible if the underlying \ufb01ber graph is connected and\nin this case. This paper investigates the heat-bath\nthe set\nversion of this random walk: At the current lattice point u\nand move\nto a random element in the integer ray (u + Z\n. The authors of [6] discovered that\nthis random walk can be seen as a discrete version of the hit-and-run algorithm [15, 26, 16]\nthat has been used frequently to sample from all the points of a polytope \u2013 not only from its\nlattice points. The popularity of the continuous version of the hit-and-run algorithm has not\nspread to its discrete analog, and not much is known about its mixing behaviour. One reason\ncan be\nis that it is already challenging to guarantee that all points in the underlying set\n\nis called a Markov basis for\n\n, an element m\n\n, we sample m\n\n\u2208 M\n\n\u2208 F\n\n\u2208 F\n\n\u2229 F\n\nm)\n\nM\n\nF\n\n\u00b7\n\nF\n\nDate: March 4, 2024.\n2010 Mathematics Subject Classi\ufb01cation. Primary: 05C81, Secondary: 37A25, 11P21.\nKey words and phrases. Heat-bath random walks, sampling, lattice points, Markov bases.\n\n1\n\n \n \n \n \n \n \n\f2\n\nCAPRICE STANLEY AND TOBIAS WINDISCH\n\n\u2229 F\n\nM\n\n, whereas for the continuous version, a\nreached by a random walk that uses moves from\nrandom sampling from the unit sphere su\ufb03ces. However, in many situations where a Markov\nbasis is known, the heat-bath random walk is evidently fast. For instance, it was shown in [3]\nthat the heat-bath random walk on contingency tables mixes rapidly when the number of\ncolumns is \ufb01xed. To work around the connectedness issue, a discrete hit-and-run algorithm\nZd. At each step in this random walk, a\nwas introduced in [1] for arbitrary \ufb01nite sets\nsubordinate and unrestricted random walk starts at the current lattice point u\nand uses\nZd. The random walk then moves from u\nthe unit vectors to collect a set of proposals S\nto a random point in S\n\nF \u2282\n\n\u2208 F\n\n\u2282\n\n.\n\nRandom walks of the heat-bath type, such as the one presented above, have been studied\nrecently in [8] in a more general context. In this paper, we explore the mixing behaviour of\nheat-bath random walks on the lattice points of polytopes with Markov bases. Throughout,\nwe assume that a Markov basis has been found already and refer to the relevant literature\nfor their computation [24, 25, 11, 17, 10, 21]. We call the underlying graph of the heat-bath\nrandom walk a compressed \ufb01ber graph (De\ufb01nition 2.5) and determine in Section 3 bounds on\nZm\u00d7d with kerZ(A)\nits graph-diameter. We prove that for any A\n, the diameter of\n0\n}\n{\n\u2208\nNd : Au = b\nkerZ(A) is\nthat use a \ufb01xed Markov bases\ncompressed \ufb01ber graphs on\n}\nbounded from above by a constant as b varies (Theorem 3.15). In contrast, we show that the\ndiameter of conventional \ufb01ber graphs grow linearly under a dilation of the underlying polytope\n(Remark 3.9). This gives rise to slow mixing"
#     },
#     {
#       "name": "Results",
#       "text": "results for conventional \ufb01ber walks as observed\nIn Section 4, we study in more detail the combinatorial and analytical structure\nin [27].\nof the transition matrices of heat-bath random walks on lattice points and prove upper and\nlower bounds on their second largest eigenvalues. We also discuss how the distribution on the\na\ufb00ects the speed of convergence (Example 4.21). Theorem 5.8 establishes with the\nmoves\ncanonical path"
#     },
#     {
#       "name": "Approach",
#       "text": "approach from [23] an upper bound on the second largest eigenvalue when the\nMarkov basis is augmenting (De\ufb01nition 5.1) and the stationary distribution is uniform. From\nthat, we conclude fast mixing"
#     },
#     {
#       "name": "Results",
#       "text": "results for random walks on lattice points in \ufb01xed dimension.\n\nNd =\n\nM \u2282\n\nu\n{\n\nM\n\n\u2208\n\n\u2229\n\nAcknowledgements. CS was partially supported by the US National Science Foundation\n(DMS 0954865). TW gratefully acknowledges the support received from the German National\nAcademic Foundation.\n\n}\n\n}\n\n\u2208\n\n\u00b7M\n\nn\n{\n\nand for any N\n\nand N\u2265N :=\n\nN\n} \u222a\n{\n\u03bbm : m\n{\n\nN>N . For n\nZ\n, \u03bb\n\nN : n > N\nQd be a \ufb01nite set, then Z\n\n:=\n. For an integer matrix A\n\n0, 1, 2, . . .\n{\nN>0, let [n] :=\n\u2208\nand N\n}\n\nConventions and Notation. The natural numbers are N :=\nN>N :=\n\nN,\n\u2208\n1, . . . , n\n. Let\n}\n{\nis the a\ufb03ne semigroup\n\u2208\nM \u2282\nZm,\nZm\u00d7d with columns a1, . . . , ad \u2208\nin Zd generated by\nwe write NA := N\n. A graph is always undirected and can have multiple loops.\nThe distance of two nodes u, v which are contained in the same connected component of a\ngraph G, i.e. the number of edges in a shortest path between u and v in G, is denoted by\nif u and v are disconnected. A mass function on a \ufb01nite\ndistG(u, v). We set distG(u, v) :=\n\u03c9\u2208\u2126 f (\u03c9) = 1. A mass function f on \u2126 is positive\nset \u2126 is a map f : \u2126\nQd such\nif f (\u03c9) > 0 for all \u03c9\nthat\n\nZd is normal if it there exists a polytope\n\nM\na1, . . . , ad}\n{\n\n[0, 1] such that\n\n\u2126. A set\n\n\u2192\n\u2208\n\nZd =\n\n\u2208 M\n\nF \u2282\n\nP \u2282\n\nM\n\nP\n\n\u221e\n\n\u2208\n\n.\n\nP \u2229\n\nF\n\n\fHEAT-BATH RANDOM WALKS WITH MARKOV BASES\n\n3\n\n2. Graphs and statistics\n\nV\n\n\u2208\n\nH\n\nH\n\nP\n\nV ,\n\n: V\n\n} 6\u2208\n\nu\u2208V H\n\n\u00d7\nv, u\n{\n\non G. Then\n\n[0, 1] such that for all v\n\n(v, u) = 0 if\nH\nV\nV\n|\nrandom walk\n\n| \u00d7 |\nH\nt(v, u) > 0. The random walk\n(u, v) = \u00b5(v)\n\nWe \ufb01rst introduce the statistical framework in which this paper lives and recall important\naspects of the interplay between graphs and statistics. A random walk on a graph G = (V, E)\n(v, u) = 1 and such that\nis a map\n\u2192\nE. When there is no ambiguity, we represent a random walk as an\n-matrix, for example when it is clear how the elements of V are ordered. Fix a\n|\nN such that\n[0, 1]\n\u2192\nH\nsuch that \u00b5(u)\nis a symmetric\nmap. A mass function \u03c0 : V\n= \u03c0. For\nsymmetric random walks, the uniform distribution on V is always a stationary distribution.\n1\nIf\n\u2265 \u2212\nand we write \u03bb(\n.\nH\nAny irreducible random walk has a unique stationary distribution [14, Corollary 1.17] and\n\u03bb(\n\n\u2208\nis reversible if there exists a mass function \u00b5 : V\n(v, u) for all u, v\n\u2208\n[0, 1] is a stationary distribution of\n\n\u03bb2(\nH\nfor the second largest eigenvalue modulus of\n\n[0, 1] measures the convergence rate: the smaller \u03bb(\n\n= n, then we denote the eigenvalues of\n\n), the faster the convergence.\n\nis irreducible if for all v, u\n\nH\nThe aim of this paper is to study random walks on lattice points that use a set of moves.\nTypically, this is achieved by constructing a graph on the set of lattice points as follows\n(compare to [7, Section 1.3] and [24, Chapter 5]).\n\nV and symmetric if\n\nV there exists t\n\nH\n\u00b7 H\n\u2192\n\nby 1 = \u03bb1(\n\n) := max\n\n\u03bb2(\n{\n\n\u2265 \u00b7 \u00b7 \u00b7 \u2265\n\nH\nif \u03c0\n\n\u03bbn(\n\n\u03bbn(\n\n\u25e6 H\n\n)\n}\n\nV\n|\n\n\u00b7 H\n\nH\n\nH\n\nH\n\nH\n\nH\n\nH\n\nH\n\nH\n\n\u2265\n\n\u2212\n\n),\n\n\u2208\n\n\u2208\n\n)\n\n)\n\n)\n\n)\n\n|\n\nDe\ufb01nition 2.1. Let\n\nwhere two nodes u, v\n\nZd be a \ufb01nite set and\nare adjacent if u\n\nF \u2282\n\n\u2208 F\n\nF\n\nA normal set\n\nZd is \ufb01nite and satis\ufb01es\n\nZd. The graph\nor v\n\nu\n\nF\n.\n\u2208 M\n\nM \u2282\nv\n\u2212\n\u2208 M\n= convQ(\n\nF\n\n)\n\nF\n\n\u2229\n\nF \u2282\n\nsets that arise in many applications, is given by the \ufb01bers of an integer matrix:\n\n\u2212\nZd. A canonic ...
#     },
#     {
#       "name": "Results",
#       "text": "results uses the Graver basis\n\ndiam(\n\nF\n\n))\n\n(\nM\n\n\u2264\n\nC\n\n\u00b7\n\nmax\n\nu\n\n{k\n\n\u2208\n: u, v\n\n.\n\u2208 F}\n\nv\n\n\u2212\nk\nGA \u2282\n\nZd for an integer matrix A\n\nF \u2208 P\n\nZm\u00d7d\n\n\u2208\n\nNd =\n\n\u2229\n\n\u2208\n\nM\n\nwith kerZ(A)\n\nis norm-like for\n\nZm\u00d7d with kerZ(A)\n\n. We refer to [4, Chapter 3] for a precise de\ufb01nition.\n0\n}\n{\nProposition 3.7. Let A\nPA. Then\nbasis of\nM\nk \u00b7 k1-norm-reducing for\n\u2208 FA,b arbitrarily and let u = v +\nP\nk1. Every gi can be replaced by a path in\nv\nk1 and hence r\n\nProof. Let\nis\nu, v\nlength. Since the Graver basis is norm-reducing for\nat most\n\nGA for A is a \ufb01nite set which\nFA,Ag+ (\n)). Now, pick\nM\nGA) of minimal\nFA,b (\nFA,b, there always exists a path of length\n)\n(\nM\n\nPA.\nPA. The Graver basis\n\nPA. Thus, de\ufb01ne C := maxg\u2208GA diam(\n\nr\ni=1 gi be a walk from u to v in\n\nkerZ(A) be a Markov\n\nbe a Markov basis for\n\nFA,Ag+\n\nNd =\n\n0\n}\n{\n\nM \u2282\n\nu\nk\n\nand\n\n\u2264 k\n\n\u2212\n\n\u2212\n\n\u2229\n\nu\n\nv\n\ni\n\n\f6\n\nCAPRICE STANLEY AND TOBIAS WINDISCH\n\nFA,b. This gives a path of length C\n\nr, hence\n(cid:3)\n\n\u00b7\n\nof length at most C and these paths stay in\nu\ndistFA,b(M)(u, v)\nk\n\n\u2212\n\n\u2264\n\nC\n\nv\n\nk1.\nZd be a polytope with dim(\n\nProposition 3.8. Let\nP \u2282\nZd for all i\nbasis for\nFi := (i\n)\n\u2229\nN, C \u2032\n)). If\ni\ni\nFi(\nM\n\u2264\n\u00b7\nQ>0 such that diam(\nC\nFi(\n\n\u00b7 P\ndiam(\n\nM\n))\n\u2264\n\n\u2208\n\u2208\n\nM\n\nP \u2229\nN. There exists a constant C \u2032\n{Fi : i\nN.\n\n\u2208\nis norm-like for\ni for all i\nC\n\n\u2208\n\nZd) > 0 and let\n\nbe a Markov\nQ>0 such that for all\n, then there exists a constant\n}\n\nM\n\nN\n\n\u2208\n\n\u00b7\n\n\u2208\n\n\u00b7\n\n\u00b7\n\ni\n\nv\n\nv\n\nk\n\nk\n\nu\n\nu\n\n\u2208\n\n\u2212\n\n\u2212\n\n\u2264\n\n{k\n\nw\u2032\n\nw, i\n\nN, i\n\nmax\n\n: u, v\n\n: u, v\n\n\u2208 Fi}\n\u2208 P \u2229\n\nfor all i\n\u2208\nZd. For all i\n\nProof. For the lower bound on the diameter, it su\ufb03ces to show the existence of C \u2032 such that\nZd) > 0,\nC \u2032\n{k\nwe can pick distinct w, w\u2032\nw\u2032\n.\nmax\n\u2208 Fi}\nTo show the upper bound, assume that\nQ\u22650 such that max\nQd such that\nZd\n\u2282\n= t\n} \u2264\nZm\u00d7n with kerZ(A)\n\nN due to Lemma 3.1. Since dim(\n\u2208 Fi and hence i\nIt su\ufb03ces to show that there\nC by Remark 3.6. Now, let\n: s\n= convQ(v1, . . . , vr) and de\ufb01ne C := max\nvs \u2212\n= t\n.\n}\n{k\nv\nu\n\u2208 Fi} \u2264\nk\n\u2212\n(cid:3)\n\nis norm-like.\ni\n\u2208 Fi} \u2264\n\nconvQ(iv1, . . . , ivr) for all i\n\nbe a Markov basis for\n\n)\n\u00b7 P\n\u2229\n: s\nivtk\n\nN, we have max\n\nvtk\n: u, v\n\nand let\nis norm-like due to Proposition 3.7 and thus for all b\n\nexists C\n\u2208\nv1, . . . , vr \u2208\nFi = (i\nSince\nivs \u2212\nmax\n{k\nRemark 3.9. Let A\nThen\nM\nsuch that\n\nM\nNA there exists C, C \u2032\n\nPA.\nQ\u22650\n\nP \u2229\nw\n\u00b7 k\n\nM\n: u, v\n\nNd =\n\n0\n}\n{\n\nk \u2264\n\n{k\n\n{k\n\n\u2212\n\n\u2212\n\nC\n\nP\n\n\u2208\n\n\u2208\n\n\u2229\n\n\u2208\n\n\u2208\n\ni.\n\nu\n\nk\n\nv\n\n\u00b7\n\n\u00b7\n\n\u00b7\n\nM\nN. This generalizes for instance [20, Proposition 2.10] and [27, Example 4.7], where\nfor all i\nlinear diameters on a ray in NA have been observed. This also implies that the construction\nof expanders from [27, Section 4] works for every right-hand side b\n\nNA.\n\n\u2264\n\n\u2264\n\n\u2208\n\n\u00b7\n\n\u00b7\n\ni\n\nC \u2032\n\ndiam(\n\nFA,ib (\n\n))\n\ni\n\nC\n\n\u2208\n\nZm\u00d7d with kerZ(A)\n\nNA, and let\nPA. Proposition 3.8 provides a new proof that the simple walk on (\n\nRemark 3.10. Let A\nbe a Markov basis\n))i\u2208N cannot\nfor\nmix rapidly. The lower bound on the diameter from Proposition 3.8 implies, in general, the\nfollowing upper bound on the edge-expansion (see for example [9, Proposition 1.30]):\n\nM\nFA,ib (\n\n, b\n0\n}\n{\n\nNd =\n\n ...
#     },
#     {
#       "name": "Introduction",
#       "text": "introduction on random walks of heat-bath type. Let\nbe \ufb01nite set. For any u\nZ)\nRF ,m(u) := (u + m\n\nZd, the ray in\n. Additionally, given a mass function \u03c0 :\n\u2208 RF ,m(x)\n\n[0, 1], we de\ufb01ne\n\nand m\n\n, if y\n\nF \u2192\n\nF \u2282\n\n\u2208 F\n\n\u2229 F\n\nF\n\n\u2208\n\n\u00b7\n\n\u03c0\nF ,m(x, y) :=\n\n\u03c0(y)\n\u03c0(RF ,m(x))\n0\n(\n\n, otherwise\n\nH\n\n[0, 1], the heat-bath random walk is\n\nfor x, y\n\n. For\n\n\u2208 F\n\nM \u2282\n\n(4.1)\n\nZd and a mass function f :\n\u03c0,f\nF ,M =\n\nf (m)\n\nM \u2192\n\u03c0\nF ,m.\n\n\u00b7 H\n\nH\n\nXm\u2208M\n\nThe underlying graph of the heat-bath random walk is the compression\nsection, we assume throughout that for all m\n\ufb01rst recall the basic properties of this random walk (compare also to [6, Lemma 2.2]).\n\nF\n, \u03bb\n1, 1\n}\n\n) and in this\n. Let us\n\nand \u03bb\n\n\u2208 M\n\n6\u2208 M\n\n\\ {\u2212\n\nM\nm\n\n\u2208\n\nZ\n\n\u00b7\n\nc(\n\nAlgorithm 1 Heat-bath random walk on compressed \ufb01ber graphs\n\n, mass functions f :\n\nM \u2192\n\n[0, 1] and \u03c0 :\n\nF \u2192\n\n[0, 1], r\n\nN\n\n\u2208\n\n\u2208 F\n\nInput:\n\nF \u2282\n\nM \u2282\n\nZd, v\nZd,\n1: procedure HeatBath:\n2:\n3:\n4:\n\nv0 := v\nFOR s = 0; s = s + 1, s < r\n\nSample m\nSample vs+1 \u2208 RF ,m(vs) according to\n\naccording to f\n\n\u2208 M\n\nRETURN v1, . . . , vr\n\n5:\n\n6:\n\nRF ,m(vs)\n\n\u2192\n\n[0, 1], y\n\n7\u2192\n\n\u03c0(y)\n\u03c0(RF ,m(vs))\n\nH\n\nF \u2282\n\nM \u2282\n\nm\n{\n\nM \u2192\n\n[0, 1] and \u03c0 :\n\nZd and\nProposition 4.1. Let\nF \u2192\n\u03c0,f\nF ,M is aperiodic, has stationary distribution \u03c0, is reversible\n(0, 1) be mass functions. Then\nwith respect to \u03c0, and all of its eigenvalues are non-negative. The random walk is irreducible\nis a Markov basis for\nif and only if\n\nZd be \ufb01nite sets. Let f :\n\n,\n\u2208 M\n\u2208 F\n\u03c0,f\nF ,M is aperiodic. By de\ufb01nition, \u03c0(x)\n\n\u2208 M\nProof. Since for any u\n\u03c0,f\nthus\nF ,M\nH\nH\nis reversible with respect to \u03c0 and \u03c0 is a stationary distribution. The statement on the\nand f \u2032 = f\n\u2032 =\n|M\u2032, then\neigenvalues is exactly [8, Lemma 1.2]. Let\n\u03c0,f \u2032\n\u2032 is a\nF ,M\u2032 and thus the heat-bath random walk is irreducible if and only if\nM\n(cid:3)\n\n\u03c0\nF ,m(u, u) > 0, there are halting states and\n\nH\n\u03c0\nF ,m(x, y) = \u03c0(y)\n\n\u03c0\nF ,m(y, x) and thus\n\n: f (m) > 0\n}\n\n: f (m) > 0\n}\nand any m\n\n\u03c0,f\nF ,M =\n\nm\n{\n\n\u2208 M\n\nM\n\nH\nMarkov basis for\n\nH\n\nH\n\nH\n\nF\n\n.\n\n.\n\nF\n\nRemark 4.2. Analyzing the speed of convergence of random walks with second largest\neigenvalues does not take the computation time of a single transition into account. From\na computational point of view, the di\ufb00erence of the simple walk and the heat-bath random\nwalk is Step 4 of Algorithm 1. However, we argue that Step 4 can be done e\ufb03ciently in\nmany cases. For instance, a hard normalizing constant of \u03c0 cancels out. If \u03c0 is the uniform\nRF ,m(v) in Step 4, which can be done\ndistribution, then one needs to sample uniformly from\n\n\fHEAT-BATH RANDOM WALKS WITH MARKOV BASES\n\n9\n\ne\ufb03ciently. If the input of Algorithm 1 is a normal set\nin\nrounding, division, and comparing operations that is linear in the number of rows of A.\n\nZd : Au\nthat is given\nRF ,m(v) can be computed with a number of\n\n-representation, then the length of the ray\n\nu\n{\n\nH\n\n\u2264\n\n=\n\nF\n\n\u2208\n\n}\n\nb\n\nThere are situations in which the heat-bath random walk provides no speed-up compared\nwith the simple walk (Example 4.3). Intuitively, adding more moves to the set of allowed\nmoves should improve the mixing time of the random walk. In general, however, this is not\ntrue for the heat-bath walk (Example 4.4).\n\nExample 4.3. For n\n\nN, consider the normal set\n\n\u2208\n0 1 1\n1 0 0\n\n\u00b7 \u00b7 \u00b7\n\u00b7 \u00b7 \u00b7\n\n,\n\n1\n0\n(cid:21)\n\nFn : ...
#     }
#   ]
# }
